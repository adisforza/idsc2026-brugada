# %% [markdown]
# # HyperParameters Search

# %% [markdown]
# ## HistBoosting

# %%
! python -m src.scripts.hyperparameter_search --model hgb_baseline
# Out:
# Hyperparameter Search: hgb_baseline
# Search Type: random
# Random search: 20 random samples
#
# --- Trial 1/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 20,
#   "max_iter": 200,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4852 ± 0.1065 | Acc: 0.7515 ± 0.0454
#
# --- Trial 2/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 40,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5529 ± 0.2466 | Acc: 0.8364 ± 0.0445
#
# --- Trial 3/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 20,
#   "max_iter": 200,
#   "class_weight": null,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4585 ± 0.1958 | Acc: 0.8364 ± 0.0647
#
# --- Trial 4/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": null,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5373 ± 0.0324 | Acc: 0.7697 ± 0.0086
#
# --- Trial 5/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4999 ± 0.0809 | Acc: 0.7394 ± 0.0086
#
# --- Trial 6/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 40,
#   "max_iter": 200,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5103 ± 0.1276 | Acc: 0.7636 ± 0.0393
#
# --- Trial 7/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5052 ± 0.0357 | Acc: 0.7455 ± 0.0148
#
# --- Trial 8/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 20,
#   "max_iter": 200,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5015 ± 0.2566 | Acc: 0.8303 ± 0.0844
#
# --- Trial 9/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 20,
#   "max_iter": 200,
#   "class_weight": null,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4387 ± 0.0991 | Acc: 0.7455 ± 0.0393
#
# --- Trial 10/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4805 ± 0.1001 | Acc: 0.7455 ± 0.0148
#
# --- Trial 11/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 40,
#   "max_iter": 200,
#   "class_weight": null,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5045 ± 0.2130 | Acc: 0.8303 ± 0.0562
#
# --- Trial 12/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 40,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5091 ± 0.0908 | Acc: 0.7576 ± 0.0374
#
# --- Trial 13/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": null,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5373 ± 0.0324 | Acc: 0.7697 ± 0.0086
#
# --- Trial 14/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 20,
#   "max_iter": 200,
#   "class_weight": null,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4864 ± 0.0653 | Acc: 0.7515 ± 0.0374
#
# --- Trial 15/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 30,
#   "max_iter": 100,
#   "class_weight": null,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5373 ± 0.0324 | Acc: 0.7697 ± 0.0086
#
# --- Trial 16/20 ---
# Parameters: {
#   "max_depth": 5,
#   "min_samples_leaf": 30,
#   "max_iter": 200,
#   "class_weight": null,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4229 ± 0.1853 | Acc: 0.8242 ± 0.0477
#
# --- Trial 17/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 20,
#   "max_iter": 100,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5275 ± 0.2427 | Acc: 0.8424 ± 0.0477
#
# --- Trial 18/20 ---
# Parameters: {
#   "max_depth": 4,
#   "min_samples_leaf": 20,
#   "max_iter": 50,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4945 ± 0.2435 | Acc: 0.8242 ± 0.0618
#
# --- Trial 19/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 20,
#   "max_iter": 50,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5005 ± 0.2169 | Acc: 0.8303 ± 0.0429
#
# --- Trial 20/20 ---
# Parameters: {
#   "max_depth": 3,
#   "min_samples_leaf": 40,
#   "max_iter": 200,
#   "class_weight": "balanced",
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5485 ± 0.2436 | Acc: 0.8303 ± 0.0454
#
# HYPERPARAMETER SEARCH RESULTS (3-Seed Average)
#
# Top 5 Configurations (sorted by brugada_f2_mean):
#
# Rank 1:
#   BRUGADA_F2: 0.5529 ± 0.2466
#   Accuracy: 0.8364 ± 0.0445
#   max_depth: 3
#   min_samples_leaf: 40
#   max_iter: 100
#   class_weight: balanced
#   enable_basal_pattern: True
#   enable_sudden_death: True
#
# Rank 2:
#   BRUGADA_F2: 0.5485 ± 0.2436
#   Accuracy: 0.8303 ± 0.0454
#   max_depth: 3
#   min_samples_leaf: 40
#   max_iter: 200
#   class_weight: balanced
#   enable_basal_pattern: True
#   enable_sudden_death: False
#
# Rank 3:
#   BRUGADA_F2: 0.5373 ± 0.0324
#   Accuracy: 0.7697 ± 0.0086
#   max_depth: 4
#   min_samples_leaf: 30
#   max_iter: 100
#   enable_basal_pattern: False
#   enable_sudden_death: False
#
# Rank 4:
#   BRUGADA_F2: 0.5373 ± 0.0324
#   Accuracy: 0.7697 ± 0.0086
#   max_depth: 4
#   min_samples_leaf: 30
#   max_iter: 100
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 5:
#   BRUGADA_F2: 0.5373 ± 0.0324
#   Accuracy: 0.7697 ± 0.0086
#   max_depth: 4
#   min_samples_leaf: 30
#   max_iter: 100
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Full results saved to: experiments/hyperparam_search_hgb_baseline_random.csv
# Best config saved to: configs/best/hgb_baseline.yml

# %% [markdown]
# ## ResNet

# %%
! python -m src.scripts.hyperparameter_search --model resnet_baseline
# Out:
# Hyperparameter Search: resnet_baseline
# Search Type: random
# Random search: 20 random samples
#
# --- Trial 1/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.01,
#   "dropout": 0.4,
#   "resnet_channels": [
#     48,
#     96,
#     192
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4759 ± 0.1580 | Acc: 0.8364 ± 0.0000
#
# --- Trial 2/20 ---
# Parameters: {
#   "learning_rate": 0.0008,
#   "weight_decay": 0.0005,
#   "dropout": 0.6,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5708 ± 0.1149 | Acc: 0.7879 ± 0.0309
#
# --- Trial 3/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.005,
#   "dropout": 0.4,
#   "resnet_channels": [
#     48,
#     96,
#     192
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6421 ± 0.1158 | Acc: 0.7515 ± 0.0521
#
# --- Trial 4/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6646 ± 0.0849 | Acc: 0.7818 ± 0.0973
#
# --- Trial 5/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.0005,
#   "dropout": 0.4,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6975 ± 0.0984 | Acc: 0.8485 ± 0.0086
#
# --- Trial 6/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.0005,
#   "dropout": 0.4,
#   "resnet_channels": [
#     48,
#     96,
#     192
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5703 ± 0.0563 | Acc: 0.8000 ± 0.0514
#
# --- Trial 7/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.6,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7023 ± 0.0863 | Acc: 0.8242 ± 0.0374
#
# --- Trial 8/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.005,
#   "dropout": 0.6,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6054 ± 0.0122 | Acc: 0.8242 ± 0.0086
#
# --- Trial 9/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.005,
#   "dropout": 0.4,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.4646 ± 0.1392 | Acc: 0.7879 ± 0.1331
#
# --- Trial 10/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.0005,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6559 ± 0.1124 | Acc: 0.8424 ± 0.0309
#
# --- Trial 11/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.0005,
#   "dropout": 0.5,
#   "resnet_channels": [
#     48,
#     96,
#     192
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7166 ± 0.1181 | Acc: 0.7818 ± 0.0535
#
# --- Trial 12/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.0005,
#   "dropout": 0.6,
#   "resnet_channels": [
#     48,
#     96,
#     192
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7357 ± 0.0936 | Acc: 0.8485 ± 0.0374
#
# --- Trial 13/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.001,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6484 ± 0.0782 | Acc: 0.7879 ± 0.0454
#
# --- Trial 14/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6414 ± 0.0315 | Acc: 0.7697 ± 0.1134
#
# --- Trial 15/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6646 ± 0.0849 | Acc: 0.7818 ± 0.0973
#
# --- Trial 16/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.005,
#   "dropout": 0.6,
#   "resnet_channels": [
#     32,
#     64,
#     128,
#     256
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5503 ± 0.0154 | Acc: 0.6727 ± 0.2062
#
# --- Trial 17/20 ---
# Parameters: {
#   "learning_rate": 0.0008,
#   "weight_decay": 0.001,
#   "dropout": 0.4,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6308 ± 0.0936 | Acc: 0.8303 ± 0.0374
#
# --- Trial 18/20 ---
# Parameters: {
#   "learning_rate": 0.0008,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6176 ± 0.0902 | Acc: 0.7879 ± 0.0600
#
# --- Trial 19/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.0005,
#   "dropout": 0.4,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6044 ± 0.0700 | Acc: 0.8303 ± 0.0086
#
# --- Trial 20/20 ---
# Parameters: {
#   "learning_rate": 0.0008,
#   "weight_decay": 0.0005,
#   "dropout": 0.6,
#   "resnet_channels": [
#     32,
#     64,
#     128
#   ],
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7052 ± 0.1274 | Acc: 0.8545 ± 0.0535
#
# HYPERPARAMETER SEARCH RESULTS (3-Seed Average)
#
# Top 5 Configurations (sorted by brugada_f2_mean):
#
# Rank 1:
#   BRUGADA_F2: 0.7357 ± 0.0936
#   Accuracy: 0.8485 ± 0.0374
#   learning_rate: 0.0015
#   weight_decay: 0.0005
#   dropout: 0.6
#   resnet_channels: [48, 96, 192]
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 2:
#   BRUGADA_F2: 0.7166 ± 0.1181
#   Accuracy: 0.7818 ± 0.0535
#   learning_rate: 0.001
#   weight_decay: 0.0005
#   dropout: 0.5
#   resnet_channels: [48, 96, 192]
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 3:
#   BRUGADA_F2: 0.7052 ± 0.1274
#   Accuracy: 0.8545 ± 0.0535
#   learning_rate: 0.0008
#   weight_decay: 0.0005
#   dropout: 0.6
#   resnet_channels: [32, 64, 128]
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 4:
#   BRUGADA_F2: 0.7023 ± 0.0863
#   Accuracy: 0.8242 ± 0.0374
#   learning_rate: 0.001
#   weight_decay: 0.01
#   dropout: 0.6
#   resnet_channels: [32, 64, 128, 256]
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 5:
#   BRUGADA_F2: 0.6975 ± 0.0984
#   Accuracy: 0.8485 ± 0.0086
#   learning_rate: 0.0015
#   weight_decay: 0.0005
#   dropout: 0.4
#   resnet_channels: [32, 64, 128, 256]
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Full results saved to: experiments/hyperparam_search_resnet_baseline_random.csv
# Best config saved to: configs/best/resnet_baseline.yml

# %% [markdown]
# ## SpatialGNN

# %%
! python -m src.scripts.hyperparameter_search --model spatial_gnn
# Out:
# Hyperparameter Search: spatial_gnn
# Search Type: random
# Random search: 20 random samples
#
# --- Trial 1/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.005,
#   "dropout": 0.6,
#   "hidden_dim": 96,
#   "num_gnn_layers": 3,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7307 ± 0.1005 | Acc: 0.7455 ± 0.1039
#
# --- Trial 2/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.015,
#   "dropout": 0.6,
#   "hidden_dim": 32,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.6,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7528 ± 0.0671 | Acc: 0.7515 ± 0.1094
#
# --- Trial 3/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "hidden_dim": 64,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7467 ± 0.0380 | Acc: 0.7758 ± 0.0562
#
# --- Trial 4/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.005,
#   "dropout": 0.4,
#   "hidden_dim": 32,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7038 ± 0.0784 | Acc: 0.7333 ± 0.0454
#
# --- Trial 5/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "hidden_dim": 96,
#   "num_gnn_layers": 3,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.6,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7003 ± 0.0056 | Acc: 0.7515 ± 0.0343
#
# --- Trial 6/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.015,
#   "dropout": 0.4,
#   "hidden_dim": 96,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7193 ± 0.0975 | Acc: 0.8242 ± 0.0086
#
# --- Trial 7/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "hidden_dim": 64,
#   "num_gnn_layers": 2,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6910 ± 0.1230 | Acc: 0.7879 ± 0.0343
#
# --- Trial 8/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.015,
#   "dropout": 0.4,
#   "hidden_dim": 96,
#   "num_gnn_layers": 2,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6462 ± 0.1016 | Acc: 0.7576 ± 0.0171
#
# --- Trial 9/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "hidden_dim": 64,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.6,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6681 ± 0.1629 | Acc: 0.7394 ± 0.0429
#
# --- Trial 10/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.01,
#   "dropout": 0.5,
#   "hidden_dim": 64,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6441 ± 0.1484 | Acc: 0.7333 ± 0.1331
#
# --- Trial 11/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.015,
#   "dropout": 0.4,
#   "hidden_dim": 64,
#   "num_gnn_layers": 3,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.6,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7254 ± 0.0453 | Acc: 0.7394 ± 0.0429
#
# --- Trial 12/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.4,
#   "hidden_dim": 32,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6854 ± 0.1231 | Acc: 0.6788 ± 0.1245
#
# --- Trial 13/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.005,
#   "dropout": 0.4,
#   "hidden_dim": 96,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6910 ± 0.1145 | Acc: 0.7636 ± 0.1941
#
# --- Trial 14/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.015,
#   "dropout": 0.4,
#   "hidden_dim": 64,
#   "num_gnn_layers": 2,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.5897 ± 0.0629 | Acc: 0.8000 ± 0.0393
#
# --- Trial 15/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.005,
#   "dropout": 0.6,
#   "hidden_dim": 96,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": false
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7263 ± 0.0602 | Acc: 0.7394 ± 0.0521
#
# --- Trial 16/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.015,
#   "dropout": 0.6,
#   "hidden_dim": 32,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.8,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6422 ± 0.1268 | Acc: 0.7879 ± 0.0309
#
# --- Trial 17/20 ---
# Parameters: {
#   "learning_rate": 0.001,
#   "weight_decay": 0.01,
#   "dropout": 0.6,
#   "hidden_dim": 96,
#   "num_gnn_layers": 3,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": true,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.6291 ± 0.0826 | Acc: 0.7273 ± 0.0393
#
# --- Trial 18/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.01,
#   "dropout": 0.4,
#   "hidden_dim": 96,
#   "num_gnn_layers": 2,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7040 ± 0.0582 | Acc: 0.6909 ± 0.1159
#
# --- Trial 19/20 ---
# Parameters: {
#   "learning_rate": 0.0012,
#   "weight_decay": 0.005,
#   "dropout": 0.6,
#   "hidden_dim": 96,
#   "num_gnn_layers": 2,
#   "gnn_type": "gcn",
#   "correlation_threshold": 0.5,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7627 ± 0.0799 | Acc: 0.7455 ± 0.0594
#
# --- Trial 20/20 ---
# Parameters: {
#   "learning_rate": 0.0015,
#   "weight_decay": 0.015,
#   "dropout": 0.6,
#   "hidden_dim": 64,
#   "num_gnn_layers": 3,
#   "gnn_type": "gat",
#   "correlation_threshold": 0.6,
#   "anatomic_weight": 0.7,
#   "enable_basal_pattern": false,
#   "enable_sudden_death": true
# }
#   Running Seed 42...
#   Running Seed 43...
#   Running Seed 44...
# Result — brugada_f2: 0.7007 ± 0.1224 | Acc: 0.7576 ± 0.0988
#
# HYPERPARAMETER SEARCH RESULTS (3-Seed Average)
#
# Top 5 Configurations (sorted by brugada_f2_mean):
#
# Rank 1:
#   BRUGADA_F2: 0.7627 ± 0.0799
#   Accuracy: 0.7455 ± 0.0594
#   learning_rate: 0.0012
#   weight_decay: 0.005
#   dropout: 0.6
#   hidden_dim: 96
#   num_gnn_layers: 2
#   gnn_type: gcn
#   correlation_threshold: 0.5
#   anatomic_weight: 0.7
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 2:
#   BRUGADA_F2: 0.7528 ± 0.0671
#   Accuracy: 0.7515 ± 0.1094
#   learning_rate: 0.0015
#   weight_decay: 0.015
#   dropout: 0.6
#   hidden_dim: 32
#   num_gnn_layers: 3
#   gnn_type: gat
#   correlation_threshold: 0.6
#   anatomic_weight: 0.7
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 3:
#   BRUGADA_F2: 0.7467 ± 0.0380
#   Accuracy: 0.7758 ± 0.0562
#   learning_rate: 0.0012
#   weight_decay: 0.01
#   dropout: 0.5
#   hidden_dim: 64
#   num_gnn_layers: 3
#   gnn_type: gat
#   correlation_threshold: 0.5
#   anatomic_weight: 0.7
#   enable_basal_pattern: False
#   enable_sudden_death: False
#
# Rank 4:
#   BRUGADA_F2: 0.7307 ± 0.1005
#   Accuracy: 0.7455 ± 0.1039
#   learning_rate: 0.0015
#   weight_decay: 0.005
#   dropout: 0.6
#   hidden_dim: 96
#   num_gnn_layers: 3
#   gnn_type: gcn
#   correlation_threshold: 0.5
#   anatomic_weight: 0.7
#   enable_basal_pattern: False
#   enable_sudden_death: True
#
# Rank 5:
#   BRUGADA_F2: 0.7263 ± 0.0602
#   Accuracy: 0.7394 ± 0.0521
#   learning_rate: 0.0012
#   weight_decay: 0.005
#   dropout: 0.6
#   hidden_dim: 96
#   num_gnn_layers: 3
#   gnn_type: gat
#   correlation_threshold: 0.5
#   anatomic_weight: 0.7
#   enable_basal_pattern: False
#   enable_sudden_death: False
#
# Full results saved to: experiments/hyperparam_search_spatial_gnn_random.csv
# Best config saved to: configs/best/spatial_gnn.yml

# %% [markdown]
# # Compare the Best Model

# %%
! python -m src.scripts.compare_models
# Out:
# Starting Model Comparison
# Will run 3 models across 5 seeds each.
#
#
# Evaluating: hgb_baseline
#   Running seed 42...
#   Running seed 43...
#   Running seed 44...
#   Running seed 45...
#   Running seed 46...
#
# Evaluating: resnet_baseline
#   Running seed 42...
#   Running seed 43...
#   Running seed 44...
#   Running seed 45...
#   Running seed 46...
#
# Evaluating: spatial_gnn
#   Running seed 42...
#   Running seed 43...
#   Running seed 44...
#   Running seed 45...
#   Running seed 46...
# all_results: [{'model_type': 'hgb_baseline', 'brugada_accuracy_mean': np.float64(0.8036363636363637), 'brugada_accuracy_std': np.float64(0.0601925285718067), 'brugada_accuracy_display': '0.8036 ± 0.0602', 'brugada_precision_mean': np.float64(0.5654545454545454), 'brugada_precision_std': np.float64(0.11757575757575756), 'brugada_precision_display': '0.5655 ± 0.1176', 'brugada_recall_mean': np.float64(0.5867942583732058), 'brugada_recall_std': np.float64(0.28513689184567603), 'brugada_recall_display': '0.5868 ± 0.2851', 'brugada_f1_mean': np.float64(0.5382010892333472), 'brugada_f1_std': np.float64(0.17471698113998865), 'brugada_f1_display': '0.5382 ± 0.1747', 'brugada_auc_mean': np.float64(0.8192014885699095), 'brugada_auc_std': np.float64(0.11786823709429556), 'brugada_auc_display': '0.8192 ± 0.1179', 'brugada_f2_mean': np.float64(0.5585636527338209), 'brugada_f2_std': np.float64(0.23428735272202025), 'brugada_f2_display': '0.5586 ± 0.2343'}, {'model_type': 'resnet_baseline', 'brugada_accuracy_mean': np.float64(0.8036363636363637), 'brugada_accuracy_std': np.float64(0.06235064799811723), 'brugada_accuracy_display': '0.8036 ± 0.0624', 'brugada_precision_mean': np.float64(0.5599719887955181), 'brugada_precision_std': np.float64(0.12552890559433227), 'brugada_precision_display': '0.5600 ± 0.1255', 'brugada_recall_mean': np.float64(0.7333333333333334), 'brugada_recall_std': np.float64(0.13333333333333333), 'brugada_recall_display': '0.7333 ± 0.1333', 'brugada_f1_mean': np.float64(0.6235039385901455), 'brugada_f1_std': np.float64(0.09674236623611662), 'brugada_f1_display': '0.6235 ± 0.0967', 'brugada_auc_mean': np.float64(0.838372093023256), 'brugada_auc_std': np.float64(0.048698585096213796), 'brugada_auc_display': '0.8384 ± 0.0487', 'brugada_f2_mean': np.float64(0.6814455164769095), 'brugada_f2_std': np.float64(0.10575267443758948), 'brugada_f2_display': '0.6814 ± 0.1058'}, {'model_type': 'spatial_gnn', 'brugada_accuracy_mean': np.float64(0.7418181818181818), 'brugada_accuracy_std': np.float64(0.06937739646668697), 'brugada_accuracy_display': '0.7418 ± 0.0694', 'brugada_precision_mean': np.float64(0.4653766233766234), 'brugada_precision_std': np.float64(0.08157728295890339), 'brugada_precision_display': '0.4654 ± 0.0816', 'brugada_recall_mean': np.float64(0.8333333333333333), 'brugada_recall_std': np.float64(0.13944333775567927), 'brugada_recall_display': '0.8333 ± 0.1394', 'brugada_f1_mean': np.float64(0.58833640524817), 'brugada_f1_std': np.float64(0.07193810690171473), 'brugada_f1_display': '0.5883 ± 0.0719', 'brugada_auc_mean': np.float64(0.8519379844961239), 'brugada_auc_std': np.float64(0.06313904711409989), 'brugada_auc_display': '0.8519 ± 0.0631', 'brugada_f2_mean': np.float64(0.7099475957485886), 'brugada_f2_std': np.float64(0.08993750471218934), 'brugada_f2_display': '0.7099 ± 0.0899'}]
#
# ROBUST MODEL COMPARISON RESULTS
#      model_type brugada_accuracy_display brugada_precision_display brugada_recall_display brugada_f1_display brugada_auc_display brugada_f2_display
#     spatial_gnn          0.7418 ± 0.0694           0.4654 ± 0.0816        0.8333 ± 0.1394    0.5883 ± 0.0719     0.8519 ± 0.0631    0.7099 ± 0.0899
# resnet_baseline          0.8036 ± 0.0624           0.5600 ± 0.1255        0.7333 ± 0.1333    0.6235 ± 0.0967     0.8384 ± 0.0487    0.6814 ± 0.1058
#    hgb_baseline          0.8036 ± 0.0602           0.5655 ± 0.1176        0.5868 ± 0.2851    0.5382 ± 0.1747     0.8192 ± 0.1179    0.5586 ± 0.2343
#
# Detailed numerical results saved to: experiments/model_comparison.csv
